# %% [markdown]
# <img src="https://dl.fbaipublicfiles.com/detectron2/Detectron2-Logo-Horz.png" width="500">

# %%
# install dependencies:
# !pip install pyyaml==5.1
# !pip install Pillow==5.3.0
# !pip install detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.7/index.html
# !gcc --version

# %%
import torch, torchvision
import torch
assert torch.__version__.startswith("1.7")
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

import numpy as np
import os, json, cv2, random, glob
from google.colab.patches import cv2_imshow
from os import listdir
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Cannot detect lamp objects

# %%
im2 = cv2.imread("/content/drive/MyDrive/Colab Notebooks/test_img.jpg")
outputs2 = predictor(im2)
v2 = Visualizer(im2[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
out2 = v2.draw_instance_predictions(outputs2["instances"].to("cpu"))
cv2_imshow(out2.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=1020x1359 at 0x7FE6D1E684A8>

# %% [markdown]
# # Fine Tuning
#  - Labelling more than 1k Lamp images in Roboflow.com

# %%
# !curl -L "https://app.roboflow.com/ds/cqo4jQYPiJ?key=tuEEpKvya1" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Register dataset

# %%
from detectron2.data.datasets import register_coco_instances
register_coco_instances("my_dataset_train", {}, "/content/train/_annotations.coco.json", "/content/train")
register_coco_instances("my_dataset_val", {}, "/content/valid/_annotations.coco.json", "/content/valid")
register_coco_instances("my_dataset_test", {}, "/content/test/_annotations.coco.json", "/content/test")

# %% [markdown]
# ## Visualize training data

# %%
my_dataset_train_metadata = MetadataCatalog.get("my_dataset_train")
dataset_dicts = DatasetCatalog.get("my_dataset_train")

import random
from detectron2.utils.visualizer import Visualizer

for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=my_dataset_train_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    cv2_imshow(vis.get_image()[:, :, ::-1])
# Out:
# WARNING [02/08 02:19:28 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/08 02:19:28 d2.data.datasets.coco]: Loaded 2466 images in COCO format from /content/train/_annotations.coco.json
# <PIL.Image.Image image mode=RGB size=208x208 at 0x7FE6D14AF9E8>
# <PIL.Image.Image image mode=RGB size=208x208 at 0x7FE6D14D4CC0>
# <PIL.Image.Image image mode=RGB size=208x208 at 0x7FE6D1579EF0>

# %% [markdown]
# ## Train and evaluate our model

# %%
#We are importing our own Trainer Module here to use the COCO validation evaluation during training. Otherwise no validation eval occurs.

from detectron2.engine import DefaultTrainer
from detectron2.evaluation import COCOEvaluator

class CocoTrainer(DefaultTrainer):

  @classmethod
  def build_evaluator(cls, cfg, dataset_name, output_folder=None):

    if output_folder is None:
        os.makedirs("coco_eval", exist_ok=True)
        output_folder = "coco_eval"

    return COCOEvaluator(dataset_name, cfg, False, output_folder)

# %%
#from .detectron2.tools.train_net import Trainer
#from detectron2.engine import DefaultTrainer
# select from modelzoo here: https://github.com/facebookresearch/detectron2/blob/master/MODEL_ZOO.md#coco-object-detection-baselines

from detectron2.config import get_cfg
#from detectron2.evaluation.coco_evaluation import COCOEvaluator
import os

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("my_dataset_train",)
cfg.DATASETS.TEST = ("my_dataset_val",)

cfg.DATALOADER.NUM_WORKERS = 4
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_X_101_32x8d_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 4
cfg.SOLVER.BASE_LR = 0.001

cfg.SOLVER.WARMUP_ITERS = 1000
cfg.SOLVER.MAX_ITER = 2000 #adjust up if val mAP is still rising, adjust down if overfit
cfg.SOLVER.STEPS = (1000, 1500)
cfg.SOLVER.GAMMA = 0.05

cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 64
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 175 #your number of classes + 1

cfg.TEST.EVAL_PERIOD = 500

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = CocoTrainer(cfg)
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [02/08 02:48:56 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=176, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=700, bias=True)
#     )
#   )
# )
# WARNING [02/08 02:48:56 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/08 02:48:56 d2.data.datasets.coco]: Loaded 2466 images in COCO format from /content/train/_annotations.coco.json
# [02/08 02:48:56 d2.data.build]: Removed 0 images with no usable annotations. 2466 images left.
# [02/08 02:48:56 d2.data.build]: Distribution of instances among all 4 categories:
# |  category  | #instances   |   category    | #instances   |  category  | #instances   |
# |:----------:|:-------------|:-------------:|:-------------|:----------:|:-------------|
# | furniture  | 0            | pendant_light | 1152         | stand_lamp | 888          |
# | table_lamp | 936          |               |              |            |              |
# |   total    | 2976         |               |              |            |              |
# [02/08 02:48:56 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [02/08 02:48:56 d2.data.build]: Using training sampler TrainingSampler
# [02/08 02:48:56 d2.data.common]: Serializing 2466 elements to byte tensors and concatenating them all ...
# [02/08 02:48:56 d2.data.common]: Serialized dataset takes 0.69 MiB
# model_final_68b088.pkl: 421MB [00:15, 26.9MB/s]
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (176, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (176,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (700, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (700,) in the model! You might want to double check if this is expected.
# [02/08 02:49:17 d2.engine.train_loop]: Starting training from iteration 0
# [02/08 02:49:59 d2.utils.events]:  eta: 1:11:01  iter: 19  total_loss: 5.893  loss_cls: 5.017  loss_box_reg: 0.8337  loss_rpn_cls: 0.03064  loss_rpn_loc: 0.009  time: 2.1305  data_time: 0.0281  lr: 1.9981e-05  max_mem: 7350M
# [02/08 02:50:43 d2.utils.events]:  eta: 1:11:20  iter: 39  total_loss: 5.211  loss_cls: 4.338  loss_box_reg: 0.8075  loss_rpn_cls: 0.02601  loss_rpn_loc: 0.008736  time: 2.1709  data_time: 0.0132  lr: 3.9961e-05  max_mem: 7350M
# [02/08 02:51:26 d2.utils.events]:  eta: 1:09:42  iter: 59  total_loss: 3.279  loss_cls: 2.451  loss_box_reg: 0.7986  loss_rpn_cls: 0.03506  loss_rpn_loc: 0.008474  time: 2.1622  data_time: 0.0113  lr: 5.9941e-05  max_mem: 7350M
# [02/08 02:52:11 d2.utils.events]:  eta: 1:10:14  iter: 79  total_loss: 2.258  loss_cls: 1.341  loss_box_reg: 0.8719  loss_rpn_cls: 0.01531  loss_rpn_loc: 0.005972  time: 2.1850  data_time: 0.0130  lr: 7.9921e-05  max_mem: 7350M
# [02/08 02:52:54 d2.utils.events]:  eta: 1:09:30  iter: 99  total_loss: 1.987  loss_cls: 1.059  loss_box_reg: 0.8616  loss_rpn_cls: 0.004555  loss_rpn_loc: 0.006281  time: 2.1774  data_time: 0.0129  lr: 9.9901e-05  max_mem: 7350M
# [02/08 02:53:37 d2.utils.events]:  eta: 1:08:23  iter: 119  total_loss: 1.608  loss_cls: 0.7076  loss_box_reg: 0.8824  loss_rpn_cls: 0.004666  loss_rpn_loc: 0.005872  time: 2.1710  data_time: 0.0142  lr: 0.00011988  max_mem: 7350M
# [02/08 02:54:21 d2.utils.events]:  eta: 1:07:48  iter: 139  total_loss: 1.305  loss_cls: 0.4334  loss_box_reg: 0.8729  loss_rpn_cls: 0.003759  loss_rpn_loc: 0.007915  time: 2.1767  data_time: 0.0170  lr: 0.00013986  max_mem: 7350M
# [02/08 02:55:04 d2.utils.events]:  eta: 1:06:52  iter: 159  total_loss: 1.167  loss_cls: 0.352  loss_box_reg: 0.8036  loss_rpn_cls: 0.004828  loss_rpn_loc: 0.009749  time: 2.1721  data_time: 0.0127  lr: 0.00015984  max_mem: 7350M
# [02/08 02:55:49 d2.utils.events]:  eta: 1:06:47  iter: 179  total_loss: 1.026  loss_cls: 0.2825  loss_box_reg: 0.7047  loss_rpn_cls: 0.001168  loss_rpn_loc: 0.008336  time: 2.1823  data_time: 0.0174  lr: 0.00017982  max_mem: 7350M
# [02/08 02:56:34 d2.utils.events]:  eta: 1:06:03  iter: 199  total_loss: 0.9007  loss_cls: 0.2845  loss_box_reg: 0.6044  loss_rpn_cls: 0.007954  loss_rpn_loc: 0.008953  time: 2.1866  data_time: 0.0170  lr: 0.0001998  max_mem: 7350M
# [02/08 02:57:18 d2.utils.events]:  eta: 1:05:26  iter: 219  total_loss: 0.8164  loss_cls: 0.186  loss_box_reg: 0.5896  loss_rpn_cls: 0.002892  loss_rpn_loc: 0.01153  time: 2.1883  data_time: 0.0168  lr: 0.00021978  max_mem: 7350M
# [02/08 02:58:02 d2.utils.events]:  eta: 1:04:42  iter: 239  total_loss: 0.8119  loss_cls: 0.2652  loss_box_reg: 0.5156  loss_rpn_cls: 0.006406  loss_rpn_loc: 0.008487  time: 2.1888  data_time: 0.0121  lr: 0.00023976  max_mem: 7350M
# [02/08 02:58:46 d2.utils.events]:  eta: 1:03:51  iter: 259  total_loss: 0.724  loss_cls: 0.1959  loss_box_reg: 0.5137  loss_rpn_cls: 0.004229  loss_rpn_loc: 0.01005  time: 2.1886  data_time: 0.0174  lr: 0.00025974  max_mem: 7350M
# [02/08 02:59:29 d2.utils.events]:  eta: 1:02:58  iter: 279  total_loss: 0.6818  loss_cls: 0.2179  loss_box_reg: 0.491  loss_rpn_cls: 0.001339  loss_rpn_loc: 0.006812  time: 2.1881  data_time: 0.0148  lr: 0.00027972  max_mem: 7350M
# [02/08 03:00:14 d2.utils.events]:  eta: 1:02:19  iter: 299  total_loss: 0.6488  loss_cls: 0.1895  loss_box_reg: 0.4451  loss_rpn_cls: 0.0003269  loss_rpn_loc: 0.006594  time: 2.1914  data_time: 0.0158  lr: 0.0002997  max_mem: 7350M
# [02/08 03:00:59 d2.utils.events]:  eta: 1:01:59  iter: 319  total_loss: 0.6364  loss_cls: 0.1831  loss_box_reg: 0.4506  loss_rpn_cls: 0.004672  loss_rpn_loc: 0.006669  time: 2.1936  data_time: 0.0169  lr: 0.00031968  max_mem: 7350M
# [02/08 03:01:43 d2.utils.events]:  eta: 1:01:27  iter: 339  total_loss: 0.6154  loss_cls: 0.1527  loss_box_reg: 0.4441  loss_rpn_cls: 0.001399  loss_rpn_loc: 0.007254  time: 2.1966  data_time: 0.0125  lr: 0.00033966  max_mem: 7350M
# [02/08 03:02:26 d2.utils.events]:  eta: 1:00:20  iter: 359  total_loss: 0.6295  loss_cls: 0.1901  loss_box_reg: 0.4175  loss_rpn_cls: 0.002437  loss_rpn_loc: 0.005795  time: 2.1933  data_time: 0.0112  lr: 0.00035964  max_mem: 7350M
# [02/08 03:03:11 d2.utils.events]:  eta: 0:59:36  iter: 379  total_loss: 0.5678  loss_cls: 0.1403  loss_box_reg: 0.3975  loss_rpn_cls: 0.001606  loss_rpn_loc: 0.005811  time: 2.1946  data_time: 0.0126  lr: 0.00037962  max_mem: 7350M
# [02/08 03:03:55 d2.utils.events]:  eta: 0:58:50  iter: 399  total_loss: 0.5765  loss_cls: 0.1162  loss_box_reg: 0.4196  loss_rpn_cls: 0.0006479  loss_rpn_loc: 0.005444  time: 2.1953  data_time: 0.0131  lr: 0.0003996  max_mem: 7350M
# [02/08 03:04:40 d2.utils.events]:  eta: 0:58:18  iter: 419  total_loss: 0.4886  loss_cls: 0.1027  loss_box_reg: 0.3589  loss_rpn_cls: 0.0007243  loss_rpn_loc: 0.004698  time: 2.1978  data_time: 0.0133  lr: 0.00041958  max_mem: 7350M
# [02/08 03:05:24 d2.utils.events]:  eta: 0:57:33  iter: 439  total_loss: 0.5634  loss_cls: 0.1503  loss_box_reg: 0.4485  loss_rpn_cls: 0.0005216  loss_rpn_loc: 0.00481  time: 2.1975  data_time: 0.0144  lr: 0.00043956  max_mem: 7350M
# [02/08 03:06:08 d2.utils.events]:  eta: 0:57:00  iter: 459  total_loss: 0.493  loss_cls: 0.1298  loss_box_reg: 0.3563  loss_rpn_cls: 0.0006504  loss_rpn_loc: 0.004819  time: 2.1992  data_time: 0.0126  lr: 0.00045954  max_mem: 7350M
# [02/08 03:06:52 d2.utils.events]:  eta: 0:56:05  iter: 479  total_loss: 0.5114  loss_cls: 0.1374  loss_box_reg: 0.3705  loss_rpn_cls: 0.0005796  loss_rpn_loc: 0.004443  time: 2.1990  data_time: 0.0099  lr: 0.00047952  max_mem: 7350M
# WARNING [02/08 03:07:36 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/08 03:07:36 d2.data.datasets.coco]: Loaded 236 images in COCO format from /content/valid/_annotations.coco.json
# [02/08 03:07:36 d2.data.build]: Distribution of instances among all 4 categories:
# |  category  | #instances   |   category    | #instances   |  category  | #instances   |
# |:----------:|:-------------|:-------------:|:-------------|:----------:|:-------------|
# | furniture  | 0            | pendant_light | 78           | stand_lamp | 85           |
# | table_lamp | 111          |               |              |            |              |
# |   total    | 274          |               |              |            |              |
# [02/08 03:07:36 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/08 03:07:36 d2.data.common]: Serializing 236 elements to byte tensors and concatenating them all ...
# [02/08 03:07:36 d2.data.common]: Serialized dataset takes 0.06 MiB
# WARNING [02/08 03:07:36 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass tasks in directly
# [02/08 03:07:36 d2.evaluation.evaluator]: Start inference on 236 images
# [02/08 03:07:39 d2.evaluation.evaluator]: Inference done 11/236. 0.2006 s / img. ETA=0:00:45
# [02/08 03:07:44 d2.evaluation.evaluator]: Inference done 36/236. 0.2011 s / img. ETA=0:00:40
# [02/08 03:07:49 d2.evaluation.evaluator]: Inference done 61/236. 0.2012 s / img. ETA=0:00:35
# [02/08 03:07:54 d2.evaluation.evaluator]: Inference done 86/236. 0.2014 s / img. ETA=0:00:30
# [02/08 03:07:59 d2.evaluation.evaluator]: Inference done 111/236. 0.2013 s / img. ETA=0:00:25
# [02/08 03:08:04 d2.evaluation.evaluator]: Inference done 136/236. 0.2012 s / img. ETA=0:00:20
# [02/08 03:08:09 d2.evaluation.evaluator]: Inference done 161/236. 0.2012 s / img. ETA=0:00:15
# [02/08 03:08:14 d2.evaluation.evaluator]: Inference done 186/236. 0.2013 s / img. ETA=0:00:10
# [02/08 03:08:19 d2.evaluation.evaluator]: Inference done 211/236. 0.2012 s / img. ETA=0:00:05
# [02/08 03:08:24 d2.evaluation.evaluator]: Inference done 236/236. 0.2012 s / img. ETA=0:00:00
# [02/08 03:08:24 d2.evaluation.evaluator]: Total inference time: 0:00:46.922968 (0.203130 s / img per device, on 1 devices)
# [02/08 03:08:24 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:46 (0.201195 s / img per device, on 1 devices)
# [02/08 03:08:25 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/08 03:08:25 d2.evaluation.coco_evaluation]: Saving results to coco_eval/coco_instances_results.json
# [02/08 03:08:25 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.05 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.440
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.833
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.376
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.551
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.497
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.594
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.601
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.650
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.600
# [02/08 03:08:25 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 44.027 | 83.330 | 37.631 |  nan  | 55.149 | 44.033 |
# [02/08 03:08:25 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/08 03:08:25 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category      | AP     | category   | AP     |
# |:-----------|:-------|:--------------|:-------|:-----------|:-------|
# | furniture  | nan    | pendant_light | 39.061 | stand_lamp | 58.127 |
# | table_lamp | 34.892 |               |        |            |        |
# [02/08 03:08:25 d2.engine.defaults]: Evaluation results for my_dataset_val in csv format:
# [02/08 03:08:25 d2.evaluation.testing]: copypaste: Task: bbox
# [02/08 03:08:25 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/08 03:08:25 d2.evaluation.testing]: copypaste: 44.0267,83.3303,37.6310,nan,55.1485,44.0332
# [02/08 03:08:25 d2.utils.events]:  eta: 0:55:06  iter: 499  total_loss: 0.5643  loss_cls: 0.1203  loss_box_reg: 0.4124  loss_rpn_cls: 0.0005037  loss_rpn_loc: 0.00503  time: 2.1982  data_time: 0.0167  lr: 0.0004995  max_mem: 7350M
# [02/08 03:09:08 d2.utils.events]:  eta: 0:54:18  iter: 519  total_loss: 0.4895  loss_cls: 0.1188  loss_box_reg: 0.3731  loss_rpn_cls: 0.0001803  loss_rpn_loc: 0.004431  time: 2.1965  data_time: 0.0142  lr: 0.00051948  max_mem: 7350M
# [02/08 03:09:51 d2.utils.events]:  eta: 0:53:34  iter: 539  total_loss: 0.4882  loss_cls: 0.12  loss_box_reg: 0.3507  loss_rpn_cls: 0.0002617  loss_rpn_loc: 0.005192  time: 2.1950  data_time: 0.0135  lr: 0.00053946  max_mem: 7350M
# [02/08 03:10:35 d2.utils.events]:  eta: 0:52:54  iter: 559  total_loss: 0.504  loss_cls: 0.1097  loss_box_reg: 0.3912  loss_rpn_cls: 0.0005201  loss_rpn_loc: 0.005739  time: 2.1959  data_time: 0.0153  lr: 0.00055944  max_mem: 7350M
# [02/08 03:11:19 d2.utils.events]:  eta: 0:52:06  iter: 579  total_loss: 0.5482  loss_cls: 0.14  loss_box_reg: 0.3785  loss_rpn_cls: 0.0003633  loss_rpn_loc: 0.00452  time: 2.1962  data_time: 0.0133  lr: 0.00057942  max_mem: 7350M
# [02/08 03:12:04 d2.utils.events]:  eta: 0:51:29  iter: 599  total_loss: 0.5158  loss_cls: 0.1059  loss_box_reg: 0.3924  loss_rpn_cls: 0.003223  loss_rpn_loc: 0.004754  time: 2.1974  data_time: 0.0164  lr: 0.0005994  max_mem: 7350M
# [02/08 03:12:47 d2.utils.events]:  eta: 0:50:38  iter: 619  total_loss: 0.451  loss_cls: 0.08632  loss_box_reg: 0.3648  loss_rpn_cls: 0.0002049  loss_rpn_loc: 0.004023  time: 2.1961  data_time: 0.0115  lr: 0.00061938  max_mem: 7350M
# [02/08 03:13:31 d2.utils.events]:  eta: 0:49:54  iter: 639  total_loss: 0.431  loss_cls: 0.07344  loss_box_reg: 0.3444  loss_rpn_cls: 0.0001844  loss_rpn_loc: 0.004469  time: 2.1960  data_time: 0.0141  lr: 0.00063936  max_mem: 7350M
# [02/08 03:14:16 d2.utils.events]:  eta: 0:49:19  iter: 659  total_loss: 0.4613  loss_cls: 0.09464  loss_box_reg: 0.3323  loss_rpn_cls: 3.148e-05  loss_rpn_loc: 0.005267  time: 2.1979  data_time: 0.0146  lr: 0.00065934  max_mem: 7350M
# [02/08 03:14:59 d2.utils.events]:  eta: 0:48:26  iter: 679  total_loss: 0.4539  loss_cls: 0.08931  loss_box_reg: 0.3297  loss_rpn_cls: 0.001005  loss_rpn_loc: 0.003967  time: 2.1968  data_time: 0.0123  lr: 0.00067932  max_mem: 7350M
# [02/08 03:15:44 d2.utils.events]:  eta: 0:47:48  iter: 699  total_loss: 0.4214  loss_cls: 0.09699  loss_box_reg: 0.3089  loss_rpn_cls: 0.0003498  loss_rpn_loc: 0.004567  time: 2.1982  data_time: 0.0157  lr: 0.0006993  max_mem: 7350M
# [02/08 03:16:27 d2.utils.events]:  eta: 0:46:56  iter: 719  total_loss: 0.3715  loss_cls: 0.07508  loss_box_reg: 0.2891  loss_rpn_cls: 0.0001201  loss_rpn_loc: 0.003728  time: 2.1969  data_time: 0.0123  lr: 0.00071928  max_mem: 7350M
# [02/08 03:17:11 d2.utils.events]:  eta: 0:46:14  iter: 739  total_loss: 0.4997  loss_cls: 0.109  loss_box_reg: 0.3734  loss_rpn_cls: 0.0002753  loss_rpn_loc: 0.004449  time: 2.1965  data_time: 0.0137  lr: 0.00073926  max_mem: 7350M
# [02/08 03:17:55 d2.utils.events]:  eta: 0:45:26  iter: 759  total_loss: 0.4393  loss_cls: 0.09756  loss_box_reg: 0.3147  loss_rpn_cls: 0.0006324  loss_rpn_loc: 0.004358  time: 2.1961  data_time: 0.0126  lr: 0.00075924  max_mem: 7350M
# [02/08 03:18:39 d2.utils.events]:  eta: 0:44:44  iter: 779  total_loss: 0.3968  loss_cls: 0.07427  loss_box_reg: 0.3121  loss_rpn_cls: 0.0002185  loss_rpn_loc: 0.005079  time: 2.1968  data_time: 0.0109  lr: 0.00077922  max_mem: 7350M
# [02/08 03:19:23 d2.utils.events]:  eta: 0:43:58  iter: 799  total_loss: 0.4553  loss_cls: 0.09547  loss_box_reg: 0.3558  loss_rpn_cls: 0.000364  loss_rpn_loc: 0.003979  time: 2.1965  data_time: 0.0140  lr: 0.0007992  max_mem: 7350M
# [02/08 03:20:07 d2.utils.events]:  eta: 0:43:15  iter: 819  total_loss: 0.3637  loss_cls: 0.07358  loss_box_reg: 0.279  loss_rpn_cls: 0.0004005  loss_rpn_loc: 0.003873  time: 2.1965  data_time: 0.0164  lr: 0.00081918  max_mem: 7350M
# [02/08 03:20:49 d2.utils.events]:  eta: 0:42:29  iter: 839  total_loss: 0.4257  loss_cls: 0.08593  loss_box_reg: 0.3423  loss_rpn_cls: 0.0001158  loss_rpn_loc: 0.004511  time: 2.1945  data_time: 0.0132  lr: 0.00083916  max_mem: 7350M
# [02/08 03:21:34 d2.utils.events]:  eta: 0:41:46  iter: 859  total_loss: 0.453  loss_cls: 0.09498  loss_box_reg: 0.3353  loss_rpn_cls: 0.0009449  loss_rpn_loc: 0.003535  time: 2.1952  data_time: 0.0123  lr: 0.00085914  max_mem: 7350M
# [02/08 03:22:19 d2.utils.events]:  eta: 0:41:04  iter: 879  total_loss: 0.4189  loss_cls: 0.07547  loss_box_reg: 0.3441  loss_rpn_cls: 0.0002382  loss_rpn_loc: 0.004894  time: 2.1964  data_time: 0.0171  lr: 0.00087912  max_mem: 7350M
# [02/08 03:23:03 d2.utils.events]:  eta: 0:40:20  iter: 899  total_loss: 0.4432  loss_cls: 0.099  loss_box_reg: 0.318  loss_rpn_cls: 0.000266  loss_rpn_loc: 0.004608  time: 2.1967  data_time: 0.0115  lr: 0.0008991  max_mem: 7350M
# [02/08 03:23:46 d2.utils.events]:  eta: 0:39:33  iter: 919  total_loss: 0.413  loss_cls: 0.07607  loss_box_reg: 0.3233  loss_rpn_cls: 0.0001538  loss_rpn_loc: 0.003979  time: 2.1954  data_time: 0.0096  lr: 0.00091908  max_mem: 7350M
# [02/08 03:24:30 d2.utils.events]:  eta: 0:38:50  iter: 939  total_loss: 0.4335  loss_cls: 0.09017  loss_box_reg: 0.3234  loss_rpn_cls: 0.0002598  loss_rpn_loc: 0.005492  time: 2.1961  data_time: 0.0111  lr: 0.00093906  max_mem: 7350M
# [02/08 03:25:14 d2.utils.events]:  eta: 0:38:06  iter: 959  total_loss: 0.4369  loss_cls: 0.1027  loss_box_reg: 0.3122  loss_rpn_cls: 0.0004297  loss_rpn_loc: 0.003779  time: 2.1963  data_time: 0.0151  lr: 0.00095904  max_mem: 7350M
# [02/08 03:25:58 d2.utils.events]:  eta: 0:37:22  iter: 979  total_loss: 0.4967  loss_cls: 0.129  loss_box_reg: 0.3384  loss_rpn_cls: 0.0003423  loss_rpn_loc: 0.004199  time: 2.1960  data_time: 0.0135  lr: 0.00097902  max_mem: 7350M
# WARNING [02/08 03:26:41 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/08 03:26:41 d2.data.datasets.coco]: Loaded 236 images in COCO format from /content/valid/_annotations.coco.json
# [02/08 03:26:41 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/08 03:26:41 d2.data.common]: Serializing 236 elements to byte tensors and concatenating them all ...
# [02/08 03:26:41 d2.data.common]: Serialized dataset takes 0.06 MiB
# WARNING [02/08 03:26:41 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass tasks in directly
# [02/08 03:26:41 d2.evaluation.evaluator]: Start inference on 236 images
# [02/08 03:26:44 d2.evaluation.evaluator]: Inference done 11/236. 0.2015 s / img. ETA=0:00:45
# [02/08 03:26:49 d2.evaluation.evaluator]: Inference done 36/236. 0.2010 s / img. ETA=0:00:40
# [02/08 03:26:54 d2.evaluation.evaluator]: Inference done 61/236. 0.2011 s / img. ETA=0:00:35
# [02/08 03:26:59 d2.evaluation.evaluator]: Inference done 86/236. 0.2011 s / img. ETA=0:00:30
# [02/08 03:27:04 d2.evaluation.evaluator]: Inference done 111/236. 0.2011 s / img. ETA=0:00:25
# [02/08 03:27:09 d2.evaluation.evaluator]: Inference done 136/236. 0.2011 s / img. ETA=0:00:20
# [02/08 03:27:14 d2.evaluation.evaluator]: Inference done 161/236. 0.2012 s / img. ETA=0:00:15
# [02/08 03:27:19 d2.evaluation.evaluator]: Inference done 186/236. 0.2012 s / img. ETA=0:00:10
# [02/08 03:27:25 d2.evaluation.evaluator]: Inference done 211/236. 0.2013 s / img. ETA=0:00:05
# [02/08 03:27:30 d2.evaluation.evaluator]: Inference done 236/236. 0.2013 s / img. ETA=0:00:00
# [02/08 03:27:30 d2.evaluation.evaluator]: Total inference time: 0:00:46.937755 (0.203194 s / img per device, on 1 devices)
# [02/08 03:27:30 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:46 (0.201301 s / img per device, on 1 devices)
# [02/08 03:27:30 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/08 03:27:30 d2.evaluation.coco_evaluation]: Saving results to coco_eval/coco_instances_results.json
# [02/08 03:27:30 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.05 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.481
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.882
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.500
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.501
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.484
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.609
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.609
# [02/08 03:27:30 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 48.102 | 88.216 | 50.036 |  nan  | 50.099 | 48.408 |
# [02/08 03:27:30 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/08 03:27:30 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category      | AP     | category   | AP     |
# |:-----------|:-------|:--------------|:-------|:-----------|:-------|
# | furniture  | nan    | pendant_light | 42.196 | stand_lamp | 50.351 |
# | table_lamp | 51.759 |               |        |            |        |
# [02/08 03:27:30 d2.engine.defaults]: Evaluation results for my_dataset_val in csv format:
# [02/08 03:27:30 d2.evaluation.testing]: copypaste: Task: bbox
# [02/08 03:27:30 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/08 03:27:30 d2.evaluation.testing]: copypaste: 48.1021,88.2164,50.0363,nan,50.0990,48.4085
# [02/08 03:27:30 d2.utils.events]:  eta: 0:36:37  iter: 999  total_loss: 0.4393  loss_cls: 0.08963  loss_box_reg: 0.3289  loss_rpn_cls: 0.0006558  loss_rpn_loc: 0.004479  time: 2.1952  data_time: 0.0107  lr: 0.000999  max_mem: 7350M
# [02/08 03:28:14 d2.utils.events]:  eta: 0:35:53  iter: 1019  total_loss: 0.441  loss_cls: 0.0865  loss_box_reg: 0.3343  loss_rpn_cls: 0.000548  loss_rpn_loc: 0.00432  time: 2.1950  data_time: 0.0145  lr: 5e-05  max_mem: 7350M
# [02/08 03:28:58 d2.utils.events]:  eta: 0:35:09  iter: 1039  total_loss: 0.3912  loss_cls: 0.08872  loss_box_reg: 0.289  loss_rpn_cls: 0.001114  loss_rpn_loc: 0.004032  time: 2.1954  data_time: 0.0123  lr: 5e-05  max_mem: 7350M
# [02/08 03:29:41 d2.utils.events]:  eta: 0:34:26  iter: 1059  total_loss: 0.3147  loss_cls: 0.04941  loss_box_reg: 0.2657  loss_rpn_cls: 0.0005699  loss_rpn_loc: 0.003612  time: 2.1949  data_time: 0.0168  lr: 5e-05  max_mem: 7350M
# [02/08 03:30:26 d2.utils.events]:  eta: 0:33:41  iter: 1079  total_loss: 0.3742  loss_cls: 0.07531  loss_box_reg: 0.2746  loss_rpn_cls: 0.0003512  loss_rpn_loc: 0.003844  time: 2.1956  data_time: 0.0155  lr: 5e-05  max_mem: 7350M
# [02/08 03:31:10 d2.utils.events]:  eta: 0:32:57  iter: 1099  total_loss: 0.3952  loss_cls: 0.07372  loss_box_reg: 0.3056  loss_rpn_cls: 0.0004377  loss_rpn_loc: 0.003699  time: 2.1957  data_time: 0.0137  lr: 5e-05  max_mem: 7350M
# [02/08 03:31:52 d2.utils.events]:  eta: 0:32:12  iter: 1119  total_loss: 0.3501  loss_cls: 0.0688  loss_box_reg: 0.2702  loss_rpn_cls: 0.0007069  loss_rpn_loc: 0.004619  time: 2.1942  data_time: 0.0094  lr: 5e-05  max_mem: 7350M
# ...
# [02/08 03:46:36 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category      | AP     | category   | AP     |
# |:-----------|:-------|:--------------|:-------|:-----------|:-------|
# | furniture  | nan    | pendant_light | 44.323 | stand_lamp | 59.487 |
# | table_lamp | 63.194 |               |        |            |        |
# [02/08 03:46:36 d2.engine.defaults]: Evaluation results for my_dataset_val in csv format:
# [02/08 03:46:36 d2.evaluation.testing]: copypaste: Task: bbox
# [02/08 03:46:36 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/08 03:46:36 d2.evaluation.testing]: copypaste: 55.6677,88.0421,62.2647,nan,46.7987,56.1057
# [02/08 03:46:36 d2.utils.events]:  eta: 0:18:17  iter: 1499  total_loss: 0.3137  loss_cls: 0.05075  loss_box_reg: 0.2604  loss_rpn_cls: 0.0003098  loss_rpn_loc: 0.004299  time: 2.1946  data_time: 0.0148  lr: 5e-05  max_mem: 7350M
# [02/08 03:47:18 d2.utils.events]:  eta: 0:17:33  iter: 1519  total_loss: 0.3694  loss_cls: 0.08044  loss_box_reg: 0.2719  loss_rpn_cls: 0.0005192  loss_rpn_loc: 0.003354  time: 2.1936  data_time: 0.0144  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:48:03 d2.utils.events]:  eta: 0:16:50  iter: 1539  total_loss: 0.3264  loss_cls: 0.06284  loss_box_reg: 0.2619  loss_rpn_cls: 0.0003056  loss_rpn_loc: 0.004009  time: 2.1941  data_time: 0.0146  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:48:46 d2.utils.events]:  eta: 0:16:05  iter: 1559  total_loss: 0.2989  loss_cls: 0.05145  loss_box_reg: 0.2266  loss_rpn_cls: 0.0004641  loss_rpn_loc: 0.003324  time: 2.1936  data_time: 0.0112  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:49:30 d2.utils.events]:  eta: 0:15:21  iter: 1579  total_loss: 0.281  loss_cls: 0.04947  loss_box_reg: 0.235  loss_rpn_cls: 0.0002293  loss_rpn_loc: 0.003926  time: 2.1934  data_time: 0.0139  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:50:14 d2.utils.events]:  eta: 0:14:37  iter: 1599  total_loss: 0.3053  loss_cls: 0.05745  loss_box_reg: 0.2468  loss_rpn_cls: 0.0003522  loss_rpn_loc: 0.004515  time: 2.1937  data_time: 0.0125  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:50:58 d2.utils.events]:  eta: 0:13:53  iter: 1619  total_loss: 0.2848  loss_cls: 0.04523  loss_box_reg: 0.2357  loss_rpn_cls: 0.0001639  loss_rpn_loc: 0.00378  time: 2.1936  data_time: 0.0155  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:51:42 d2.utils.events]:  eta: 0:13:09  iter: 1639  total_loss: 0.322  loss_cls: 0.05921  loss_box_reg: 0.2491  loss_rpn_cls: 0.0001691  loss_rpn_loc: 0.003091  time: 2.1936  data_time: 0.0120  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:52:25 d2.utils.events]:  eta: 0:12:25  iter: 1659  total_loss: 0.3178  loss_cls: 0.06028  loss_box_reg: 0.2457  loss_rpn_cls: 0.0004953  loss_rpn_loc: 0.003296  time: 2.1934  data_time: 0.0134  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:53:09 d2.utils.events]:  eta: 0:11:42  iter: 1679  total_loss: 0.2958  loss_cls: 0.05194  loss_box_reg: 0.2447  loss_rpn_cls: 0.0002157  loss_rpn_loc: 0.003392  time: 2.1937  data_time: 0.0155  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:53:54 d2.utils.events]:  eta: 0:10:58  iter: 1699  total_loss: 0.34  loss_cls: 0.08081  loss_box_reg: 0.2569  loss_rpn_cls: 0.0004284  loss_rpn_loc: 0.004286  time: 2.1940  data_time: 0.0129  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:54:37 d2.utils.events]:  eta: 0:10:14  iter: 1719  total_loss: 0.2909  loss_cls: 0.06316  loss_box_reg: 0.2254  loss_rpn_cls: 0.0003976  loss_rpn_loc: 0.003221  time: 2.1934  data_time: 0.0171  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:55:20 d2.utils.events]:  eta: 0:09:30  iter: 1739  total_loss: 0.3105  loss_cls: 0.05653  loss_box_reg: 0.2341  loss_rpn_cls: 0.0004778  loss_rpn_loc: 0.003371  time: 2.1933  data_time: 0.0112  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:56:04 d2.utils.events]:  eta: 0:08:46  iter: 1759  total_loss: 0.3277  loss_cls: 0.05084  loss_box_reg: 0.2523  loss_rpn_cls: 0.0003172  loss_rpn_loc: 0.003264  time: 2.1934  data_time: 0.0124  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:56:49 d2.utils.events]:  eta: 0:08:02  iter: 1779  total_loss: 0.3108  loss_cls: 0.05895  loss_box_reg: 0.2419  loss_rpn_cls: 0.0004006  loss_rpn_loc: 0.003771  time: 2.1936  data_time: 0.0137  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:57:33 d2.utils.events]:  eta: 0:07:18  iter: 1799  total_loss: 0.2732  loss_cls: 0.06034  loss_box_reg: 0.202  loss_rpn_cls: 0.0004188  loss_rpn_loc: 0.002921  time: 2.1937  data_time: 0.0139  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:58:18 d2.utils.events]:  eta: 0:06:34  iter: 1819  total_loss: 0.2853  loss_cls: 0.05718  loss_box_reg: 0.2213  loss_rpn_cls: 0.0003497  loss_rpn_loc: 0.003631  time: 2.1942  data_time: 0.0117  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:59:02 d2.utils.events]:  eta: 0:05:51  iter: 1839  total_loss: 0.3416  loss_cls: 0.06501  loss_box_reg: 0.2659  loss_rpn_cls: 0.0003393  loss_rpn_loc: 0.003454  time: 2.1943  data_time: 0.0127  lr: 2.5e-06  max_mem: 7350M
# [02/08 03:59:45 d2.utils.events]:  eta: 0:05:07  iter: 1859  total_loss: 0.3163  loss_cls: 0.05694  loss_box_reg: 0.242  loss_rpn_cls: 0.0003497  loss_rpn_loc: 0.00317  time: 2.1941  data_time: 0.0158  lr: 2.5e-06  max_mem: 7350M
# [02/08 04:00:29 d2.utils.events]:  eta: 0:04:23  iter: 1879  total_loss: 0.3449  loss_cls: 0.07022  loss_box_reg: 0.2608  loss_rpn_cls: 0.001661  loss_rpn_loc: 0.004578  time: 2.1939  data_time: 0.0131  lr: 2.5e-06  max_mem: 7350M
# [02/08 04:01:14 d2.utils.events]:  eta: 0:03:39  iter: 1899  total_loss: 0.3066  loss_cls: 0.06276  loss_box_reg: 0.245  loss_rpn_cls: 0.0001753  loss_rpn_loc: 0.003442  time: 2.1945  data_time: 0.0110  lr: 2.5e-06  max_mem: 7350M
# [02/08 04:01:59 d2.utils.events]:  eta: 0:02:55  iter: 1919  total_loss: 0.2642  loss_cls: 0.05994  loss_box_reg: 0.2062  loss_rpn_cls: 0.0004149  loss_rpn_loc: 0.002622  time: 2.1951  data_time: 0.0120  lr: 2.5e-06  max_mem: 7350M
# [02/08 04:02:43 d2.utils.events]:  eta: 0:02:11  iter: 1939  total_loss: 0.3115  loss_cls: 0.05678  loss_box_reg: 0.2469  loss_rpn_cls: 0.0003824  loss_rpn_loc: 0.00321  time: 2.1951  data_time: 0.0131  lr: 2.5e-06  max_mem: 7350M
# [02/08 04:03:27 d2.utils.events]:  eta: 0:01:27  iter: 1959  total_loss: 0.3284  loss_cls: 0.05339  loss_box_reg: 0.2671  loss_rpn_cls: 0.0002899  loss_rpn_loc: 0.003568  time: 2.1953  data_time: 0.0160  lr: 2.5e-06  max_mem: 7350M
# [02/08 04:04:11 d2.utils.events]:  eta: 0:00:43  iter: 1979  total_loss: 0.3411  loss_cls: 0.06255  loss_box_reg: 0.2722  loss_rpn_cls: 0.0003562  loss_rpn_loc: 0.00452  time: 2.1952  data_time: 0.0143  lr: 2.5e-06  max_mem: 7350M
# WARNING [02/08 04:04:59 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/08 04:04:59 d2.data.datasets.coco]: Loaded 236 images in COCO format from /content/valid/_annotations.coco.json
# [02/08 04:04:59 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/08 04:04:59 d2.data.common]: Serializing 236 elements to byte tensors and concatenating them all ...
# [02/08 04:04:59 d2.data.common]: Serialized dataset takes 0.06 MiB
# WARNING [02/08 04:04:59 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass tasks in directly
# [02/08 04:04:59 d2.evaluation.evaluator]: Start inference on 236 images
# [02/08 04:05:02 d2.evaluation.evaluator]: Inference done 11/236. 0.2018 s / img. ETA=0:00:45
# [02/08 04:05:07 d2.evaluation.evaluator]: Inference done 36/236. 0.2016 s / img. ETA=0:00:40
# [02/08 04:05:12 d2.evaluation.evaluator]: Inference done 61/236. 0.2013 s / img. ETA=0:00:35
# [02/08 04:05:17 d2.evaluation.evaluator]: Inference done 86/236. 0.2015 s / img. ETA=0:00:30
# [02/08 04:05:22 d2.evaluation.evaluator]: Inference done 111/236. 0.2015 s / img. ETA=0:00:25
# [02/08 04:05:27 d2.evaluation.evaluator]: Inference done 136/236. 0.2018 s / img. ETA=0:00:20
# [02/08 04:05:33 d2.evaluation.evaluator]: Inference done 161/236. 0.2021 s / img. ETA=0:00:15
# [02/08 04:05:38 d2.evaluation.evaluator]: Inference done 186/236. 0.2020 s / img. ETA=0:00:10
# [02/08 04:05:43 d2.evaluation.evaluator]: Inference done 211/236. 0.2019 s / img. ETA=0:00:05
# [02/08 04:05:48 d2.evaluation.evaluator]: Inference done 236/236. 0.2019 s / img. ETA=0:00:00
# [02/08 04:05:48 d2.evaluation.evaluator]: Total inference time: 0:00:47.114872 (0.203960 s / img per device, on 1 devices)
# [02/08 04:05:48 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:46 (0.201875 s / img per device, on 1 devices)
# [02/08 04:05:48 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/08 04:05:48 d2.evaluation.coco_evaluation]: Saving results to coco_eval/coco_instances_results.json
# [02/08 04:05:48 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.05 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.553
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.880
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.630
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.675
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.679
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.681
# [02/08 04:05:48 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 55.276 | 88.018 | 63.026 |  nan  | 46.799 | 55.683 |
# [02/08 04:05:48 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/08 04:05:48 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category      | AP     | category   | AP     |
# |:-----------|:-------|:--------------|:-------|:-----------|:-------|
# | furniture  | nan    | pendant_light | 45.228 | stand_lamp | 59.234 |
# | table_lamp | 61.365 |               |        |            |        |
# [02/08 04:05:48 d2.engine.defaults]: Evaluation results for my_dataset_val in csv format:
# [02/08 04:05:48 d2.evaluation.testing]: copypaste: Task: bbox
# [02/08 04:05:48 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/08 04:05:48 d2.evaluation.testing]: copypaste: 55.2758,88.0183,63.0260,nan,46.7987,55.6832
# [02/08 04:05:48 d2.utils.events]:  eta: 0:00:00  iter: 1999  total_loss: 0.3145  loss_cls: 0.04527  loss_box_reg: 0.2469  loss_rpn_cls: 0.000207  loss_rpn_loc: 0.003135  time: 2.1958  data_time: 0.0179  lr: 2.5e-06  max_mem: 7350M
# [02/08 04:05:48 d2.engine.hooks]: Overall training speed: 1998 iterations in 1:13:07 (2.1958 s / it)
# [02/08 04:05:48 d2.engine.hooks]: Total training time: 1:16:27 (0:03:20 on hooks)
# WARNING [02/08 04:05:48 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/08 04:05:48 d2.data.datasets.coco]: Loaded 236 images in COCO format from /content/valid/_annotations.coco.json
# [02/08 04:05:48 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/08 04:05:48 d2.data.common]: Serializing 236 elements to byte tensors and concatenating them all ...
# [02/08 04:05:48 d2.data.common]: Serialized dataset takes 0.06 MiB
# WARNING [02/08 04:05:48 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass tasks in directly
# [02/08 04:05:48 d2.evaluation.evaluator]: Start inference on 236 images
# [02/08 04:05:53 d2.evaluation.evaluator]: Inference done 22/236. 0.2027 s / img. ETA=0:00:43
# [02/08 04:05:58 d2.evaluation.evaluator]: Inference done 47/236. 0.2022 s / img. ETA=0:00:38
# [02/08 04:06:03 d2.evaluation.evaluator]: Inference done 72/236. 0.2016 s / img. ETA=0:00:33
# [02/08 04:06:08 d2.evaluation.evaluator]: Inference done 97/236. 0.2017 s / img. ETA=0:00:28
# [02/08 04:06:13 d2.evaluation.evaluator]: Inference done 122/236. 0.2015 s / img. ETA=0:00:23
# [02/08 04:06:18 d2.evaluation.evaluator]: Inference done 147/236. 0.2015 s / img. ETA=0:00:18
# [02/08 04:06:23 d2.evaluation.evaluator]: Inference done 172/236. 0.2014 s / img. ETA=0:00:12
# [02/08 04:06:28 d2.evaluation.evaluator]: Inference done 197/236. 0.2013 s / img. ETA=0:00:07
# [02/08 04:06:33 d2.evaluation.evaluator]: Inference done 222/236. 0.2013 s / img. ETA=0:00:02
# [02/08 04:06:36 d2.evaluation.evaluator]: Total inference time: 0:00:46.958678 (0.203284 s / img per device, on 1 devices)
# [02/08 04:06:36 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:46 (0.201260 s / img per device, on 1 devices)
# [02/08 04:06:36 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/08 04:06:36 d2.evaluation.coco_evaluation]: Saving results to coco_eval/coco_instances_results.json
# [02/08 04:06:36 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.05 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.553
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.880
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.630
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.468
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.557
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.588
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.675
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.679
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.550
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.681
# [02/08 04:06:36 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 55.276 | 88.018 | 63.026 |  nan  | 46.799 | 55.683 |
# [02/08 04:06:36 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/08 04:06:36 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category      | AP     | category   | AP     |
# |:-----------|:-------|:--------------|:-------|:-----------|:-------|
# | furniture  | nan    | pendant_light | 45.228 | stand_lamp | 59.234 |
# | table_lamp | 61.365 |               |        |            |        |
# [02/08 04:06:36 d2.engine.defaults]: Evaluation results for my_dataset_val in csv format:
# [02/08 04:06:36 d2.evaluation.testing]: copypaste: Task: bbox
# [02/08 04:06:36 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [02/08 04:06:36 d2.evaluation.testing]: copypaste: 55.2758,88.0183,63.0260,nan,46.7987,55.6832

# %%
# Look at training curves in tensorboard:
# %load_ext tensorboard
# %tensorboard --logdir output

# %%
#test evaluation
from detectron2.data import DatasetCatalog, MetadataCatalog, build_detection_test_loader
from detectron2.evaluation import COCOEvaluator, inference_on_dataset

cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.85
predictor = DefaultPredictor(cfg)
evaluator = COCOEvaluator("my_dataset_test", cfg, False, output_dir="./output/")
val_loader = build_detection_test_loader(cfg, "my_dataset_test")
inference_on_dataset(trainer.model, val_loader, evaluator)
# Out:
# WARNING [02/08 04:06:43 d2.evaluation.coco_evaluation]: COCO Evaluator instantiated using config, this is deprecated behavior. Please pass tasks in directly
# WARNING [02/08 04:06:43 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [02/08 04:06:43 d2.data.datasets.coco]: Loaded 118 images in COCO format from /content/test/_annotations.coco.json
# [02/08 04:06:43 d2.data.build]: Distribution of instances among all 4 categories:
# |  category  | #instances   |   category    | #instances   |  category  | #instances   |
# |:----------:|:-------------|:-------------:|:-------------|:----------:|:-------------|
# | furniture  | 0            | pendant_light | 41           | stand_lamp | 51           |
# | table_lamp | 40           |               |              |            |              |
# |   total    | 132          |               |              |            |              |
# [02/08 04:06:43 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [02/08 04:06:43 d2.data.common]: Serializing 118 elements to byte tensors and concatenating them all ...
# [02/08 04:06:43 d2.data.common]: Serialized dataset takes 0.03 MiB
# [02/08 04:06:43 d2.evaluation.evaluator]: Start inference on 118 images
# [02/08 04:06:45 d2.evaluation.evaluator]: Inference done 11/118. 0.2017 s / img. ETA=0:00:21
# [02/08 04:06:50 d2.evaluation.evaluator]: Inference done 36/118. 0.2012 s / img. ETA=0:00:16
# [02/08 04:06:55 d2.evaluation.evaluator]: Inference done 61/118. 0.2011 s / img. ETA=0:00:11
# [02/08 04:07:00 d2.evaluation.evaluator]: Inference done 86/118. 0.2014 s / img. ETA=0:00:06
# [02/08 04:07:06 d2.evaluation.evaluator]: Inference done 111/118. 0.2017 s / img. ETA=0:00:01
# [02/08 04:07:07 d2.evaluation.evaluator]: Total inference time: 0:00:23.080695 (0.204254 s / img per device, on 1 devices)
# [02/08 04:07:07 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:22 (0.201667 s / img per device, on 1 devices)
# [02/08 04:07:07 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [02/08 04:07:07 d2.evaluation.coco_evaluation]: Saving results to ./output/coco_instances_results.json
# [02/08 04:07:07 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# COCOeval_opt.evaluate() finished in 0.02 seconds.
# Accumulating evaluation results...
# COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.643
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.939
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.748
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.441
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.652
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.652
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.759
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.759
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.567
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.765
# [02/08 04:07:07 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm   |  APl   |
# |:------:|:------:|:------:|:-----:|:------:|:------:|
# | 64.253 | 93.945 | 74.815 |  nan  | 44.109 | 65.153 |
# [02/08 04:07:07 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [02/08 04:07:07 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category      | AP     | category   | AP     |
# |:-----------|:-------|:--------------|:-------|:-----------|:-------|
# | furniture  | nan    | pendant_light | 54.132 | stand_lamp | 70.947 |
# | table_lamp | 67.680 |               |        |            |        |
# OrderedDict([('bbox',
#               {'AP': 64.2527892842917,
#                'AP-furniture': nan,
#                'AP-pendant_light': 54.13164773907195,
#                'AP-stand_lamp': 70.9471800510779,
#                'AP-table_lamp': 67.67954006272525,
#                'AP50': 93.94451492635885,
#                'AP75': 74.8154243339296,
#                'APl': 65.15265047831528,
#                'APm': 44.10891089108911,
#                'APs': nan})])

# %%
# %ls ./output/
# Out:
# coco_instances_results.json                        last_checkpoint
# events.out.tfevents.1612752537.23b341131aa3.287.0  metrics.json
# instances_predictions.pth                          model_final.pth

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.DATASETS.TEST = ("my_dataset_test", )   
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7   # set the testing threshold for this model
predictor = DefaultPredictor(cfg)
test_metadata = MetadataCatalog.get("my_dataset_test")

# %%
from detectron2.utils.visualizer import ColorMode
import glob

for imageName in glob.glob('/content/test/*jpg'):
  im = cv2.imread(imageName)
  outputs = predictor(im)
  v = Visualizer(im[:, :, ::-1],
                metadata=test_metadata, 
                scale=0.8
                 )
  out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
  cv2_imshow(out.get_image()[:, :, ::-1])

# %% [markdown]
# # It only detects lamps
#  - Detect 2 table lamps but one of those is a balloon :(
#  - Miss 1 stand lamp
#  - Need more work

# %%
im = cv2.imread("/content/drive/MyDrive/Colab Notebooks/test_img.jpg")
outputs = predictor(im)
v = Visualizer(im[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
cv2_imshow(out.get_image()[:, :, ::-1])
