# %%
from feature_extraction import *

# %%
# 이미지에서 특징 추출한 csv 파일 생성
# get_image_feature_vectors('couch')

# %%
# 이미지에서 특징 추출한 csv 파일 생성
# get_image_feature_vectors('clock')

# %%
recommendation()
# Out:
# Wait a second please!
# item1 : https://ohou.se/productions/494047
# item2 : https://ohou.se/productions/682866
# item3 : https://ohou.se/productions/566982
# item4 : https://ohou.se/productions/170945
# item5 : https://ohou.se/productions/607767
# How were those items?
