# %%
import feature_extraction

# %%
feature_extraction.recommendation('pics/input.jpg')
# Out:
# 1번째 아이템 : https://ohou.se/productions/444239
# 2번째 아이템 : https://ohou.se/productions/604406
# 3번째 아이템 : https://ohou.se/productions/127303
# 4번째 아이템 : https://ohou.se/productions/383102
# 5번째 아이템 : https://ohou.se/productions/318928

# %%
from feature_extraction_class import Recommendation

# %%
obj = Recommendation('pics/input.jpg')

# %%
obj.recommendation()
# Out:
# 1번째 아이템 : https://ohou.se/productions/444239
# 2번째 아이템 : https://ohou.se/productions/604406
# 3번째 아이템 : https://ohou.se/productions/127303
# 4번째 아이템 : https://ohou.se/productions/383102
# 5번째 아이템 : https://ohou.se/productions/318928
